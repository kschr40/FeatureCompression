# %%
import openml
import numpy as np

# %%
datasetname = 'california'
dataset = openml.datasets.get_dataset(dataset_id=datasetname, version=1)
X, y,_,_ = dataset.get_data(target=dataset.default_target_attribute)

# %%
X.shape
# Out:
# (20634, 8)

# %%
#openml.config.apikey = 'FILL_IN_OPENML_API_KEY'  # set the OpenML Api Key
SUITE_ID = 336 # Regression on numerical features
#SUITE_ID = 337 # Classification on numerical features
#SUITE_ID = 335 # Regression on numerical and categorical features
#SUITE_ID = 334 # Classification on numerical and categorical features
benchmark_suite = openml.study.get_suite(SUITE_ID)  # obtain the benchmark suite

# %%
type(benchmark_suite.tasks)
# Out:
# list

# %%
task_id = benchmark_suite.tasks[1]

# %%
task_id
# Out:
# 361073

# %%
task = openml.tasks.get_task(task_id)  # download the OpenML task

# %%
task
# Out:
# OpenML Regression Task
# ...
# Task Type Description: https://www.openml.org/tt/TaskType.SUPERVISED_REGRESSION
# Task ID..............: 361073
# Task URL.............: https://www.openml.org/t/361073
# Estimation Procedure.: crossvalidation
# Evaluation Measure...: root_mean_squared_error
# Target Feature.......: foo

# %%
dataset = task.get_dataset()

# %%
dataset
# Out:
# OpenML Dataset
# ...
# Name.........: pol
# Version......: 11
# Format.......: arff
# Upload Date..: 2022-07-05 20:47:59
# Licence......: Public
# Download URL.: https://api.openml.org/data/v1/download/22103258/pol.arff
# OpenML URL...: https://www.openml.org/d/44133
# # of features: None

# %%
X, y, categorical_indicator, attribute_names = dataset.get_data(
    dataset_format="dataframe", target=dataset.default_target_attribute
)

# %%
X.T[np.array(categorical_indicator) == False].T.shape
# Out:
# (20634, 8)

# %%
np.array(categorical_indicator)
X[:, [not ind for ind in np.array(categorical_indicator)]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\k_schr40\.conda\envs\canopy\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), [True, True, True, True, True, True, True, True])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 np.array(categorical_indicator)
# ----> 2 X[:, [not ind for ind in np.array(categorical_indicator)]]
#
# ...

# %%
X[:,[not ind for ind in categorical_indicator]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\k_schr40\.conda\envs\canopy\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), [True, True, True, True, True, True, True, True])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 X[:,[not ind for ind in categorical_indicator]]
#
# File c:\Users\k_schr40\.conda\envs\canopy\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
# ...

# %%
eeg, *_ = dataset.get_data()
# Out:
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 eeg, *_ = dataset.get_data()
#
# File ~/.local/lib/python3.12/site-packages/openml/datasets/dataset.py:820, in OpenMLDataset.get_data(self, target, include_row_id, include_ignore_attribute, dataset_format)
#     811 if dataset_format == "array":
#     812     warnings.warn(
#     813         "Support for `dataset_format='array'` will be removed in 0.15,"
#     814         "start using `dataset_format='dataframe' to ensure your code "
#    (...)
#     818         stacklevel=2,
#     819     )
# --> 820 data, categorical, attribute_names = self._load_data()
#     822 to_exclude = []
#     823 if not include_row_id and self.row_id_attribute is not None:
#
# File ~/.local/lib/python3.12/site-packages/openml/datasets/dataset.py:607, in OpenMLDataset._load_data(self)
# ...

# %%
dataset.name
